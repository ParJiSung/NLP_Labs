# %% [markdown]
# (Placeholder for your group #)
#
# (Placeholder for your names)
#
# (Placeholder for your i-numbers)
#
# Use of genAI tools (e.g. chatGPT), websites (e.g. stackoverflow): list websites where you found code (or other info) as well as include information on how you used genAI tools
#
# Mention names of collaborators outside your group

# %% [markdown]
# # NLP 2026
# # Lab 1: From Tokens to Language Models
#
# As discussed in the first lectures, tokenization is a fundamental step in **Natural Language Processing (NLP)** 🧠💬 that transforms raw text into structured data for computational models. In this lab, you will explore different **tokenization techniques** 📝, preprocess text data 🔍, and implement **tokenization pipelines** using popular NLP libraries 🏗️. Next, we explore N-gram language models 📊 as a foundational approach 🧱 to modeling natural language statistically 📈. These models form the conceptual foundation 🧠 of the neural language models 🤖🧠 that we will explore later in the course 🚀📚.
#
# You will also gain **hands-on experience** with **Hugging Face Datasets 🤗📚**, while assessing the impact of tokenization choices on downstream NLP tasks.
#
# By the end of this lab, you will have a **strong foundation** in tokenization techniques and be able to apply them effectively in **real-world NLP applications**, including implementing a N-gram language modeling pipeline🌍.
#
# ---
#
# ### 🎯 **Learning Goals**
#
# By the end of this lab, you should be able to:
#
# ✅ **Understand the role of tokenization in NLP** 🧠💡
# ✅ **Explain why tokenization is important** and how it affects text processing 📖🔍
# ✅ **Implement different tokenization techniques** – Apply **word** 📝, **subword** 🔢, and **character-level** 🔠 tokenization using built-in libraries.
# ✅ **Use Hugging Face Datasets** 🤗📊 – Load and preprocess text datasets efficiently.
# ✅ **Evaluate tokenization impact** 📉🔎 – Analyze how different tokenization methods influence model performance.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity**, and **multilingual tokenization** 🌍.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity** and **multilingual tokenization** 🌍.
# ✅ **Build and use N-gram language models** 🧠📊 - Understand how unigrams, bigrams and higher-order n-grams capture context in text, implement efficient N-gram counting with Python and design an object-oriented N-gram Language Model that supports probability lookup and text generation.
# ✅ **Generate, smooth and evaluate language models** 🚀📉 - Apply different techniques for text generation and compare models with different values of $N$ and advanced techniques such as interpolation or backoff.
#
# ### Score breakdown
#
# | Exercise            | Points |
# |---------------------|--------|
# | [Exercise 1](#e1)   | 3      |
# | [Exercise 2](#e2)   | 6      |
# | [Exercise 3](#e3)   | 4      |
# | [Exercise 4](#e4)   | 6      |
# | [Exercise 5](#e5)   | 4      |
# | [Exercise 6](#e6)   | 7      |
# | [Exercise 7](#e7)   | 4      |
# | [Exercise 8](#e8)   | 4      |
# | [Exercise 9](#e9)   | 4      |
# | [Exercise 10](#e10) | 6      |
# | [Exercise 11](#e11) | 4      |
# | [Exercise 12](#e12) | 4      |
# | [Exercise 13](#e13) | 4      |
# | [Exercise 14](#e14) | 4      |
# | [Exercise 15](#e15) | 4      |
# | [Exercise 16](#e16) | 4      |
# | [Exercise 17](#e17) | 4      |
# | [Exercise 18](#e18) | 4      |
# | [Exercise 19](#e19) | 20     |
# | Total               | 100    |
#
# This score will be scaled down to X.X and that will be your final lab score.
#
# ### 📌 **Instructions for Delivery** (📅 **Deadline: X/Feb 18:00**, 🎭 *wildcards possible*)
#
# ✅ **Submission Requirements**
# + 📄 You need to submit a **notebook** 📓 with the code, appropriate comments and figures in all questions. Make sure to have a mix of code (some explanations needed if not clear what you implement), figures to support the answers or your claims and proper amount of text to explain your reasoning, answer etc.
# + ⚡ Make sure that **all cells are executed properly** ⚙️ and that **all figures/results/plots** 📊 you include in the report are also visible in your **executed notebook**.
# + You can work on Google Collab (or other environments), but you need to make sure that your delivered notebook is executed properly.
#
# ✅ **Collaboration & Integrity**
# + 🗣️ While you may **discuss** the lab with others, you must **write your solutions with your group only**. If you **discuss specific tasks** with others, please **include their names** below.
# + 📜 **Honor Code applies** to this lab. For more details, check **Syllabus §7.2** ⚖️.
# + 📢 **Mandatory Disclosure**:
#    - Any **websites** 🌐 (e.g., **Stack Overflow** 💡) or **other resources** used must be **listed and disclosed**.
#    - Any **GenAI tools** 🤖 (e.g., **ChatGPT**) used must be **explicitly mentioned**.
#    - 🚨 **Failure to disclose these resources is a violation of academic integrity**. See **Syllabus §7.3** for details.

# %% [markdown]
# **A note from Jerry on using Language Models (LMs)**
#
# If you try hard enough, you will likely get away with cheating (that does not only apply to LMs). Fortunately, our job is not to police, but rather to educate you. So, please consider the following:
#
# - We assume that you are taking this course to learn something! LMs are not always right (they often fail in silly ways). This course should prepare you to detect when they are wrong!
# - We don't restrict the use of LMs because we see the value of being helped when coding (esp. in the context of a course like NLP). Based on what we saw last year in your deliverables, it's pretty clear when you "copy" some code and then you struggle to interpret the results. This is the essence of this course and of the skills you should try build for yourself: Many people can run fancy models these days but not many people can interpret the results correctly. Try to be the latter ones.

# %% [markdown]
# ## 0. Preparation
#
# In this section we will import the necessary libraries. But first we will explain how to install a python environment using conda. You don't have to do it this way, and maybe you already have one prepared.
#
# First, you can install Miniconda environment manager. Here are the instructions https://www.anaconda.com/docs/getting-started/miniconda/install.
# It can create virtual environments with different python versions and separately installed libraries (useful if  you work on several projects). You can read more about managing environments here: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
# You might need a restart of your system to complete the installation.
#
# The commands below are commented out so that you don't run them by mistake. You will have to copy them to the terminal of your operating system.

# %% [markdown]
# This command creates a new environment called `nlplab2026` (you can change the name if you'd like) and python version `3.12`.

# %%
#conda create -n nlplab2026 python=3.13 -y

# %% [markdown]
# The environment should be installed, but it is not activated yet. To do it you can use the following command:

# %%
#conda init cmd.exe
#conda activate nlplab2026

# %% [markdown]
# The activation of the environment is indicated by the prompt (the name of the environment should be in parentheses), for example: `(nlplab2026) pawelmaka@MacBook ~ % `
#
# Now, we are ready to install the required packages using `pip`:

# %%
#pip install --user --upgrade jupyter
#pip install tqdm
#pip install datasets
#pip install matplotlib
#pip install numpy
#pip install pandas

# %% [markdown]
# Sometimes, the libraries don't work together well on some systems. This situation could necessitate the installation of a library's particular version. To do so you can use the following command (putting the library and version you need)

# %%
#pip install matplotlib==3.10.8 --force-reinstall -v

# %% [markdown]
# When you are starting jupyter notebook make sure to first activate the environment `nlplab2026`.

# %% [markdown]
# ### Imports

# %%
import re
from collections import Counter

import datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm

# %% [markdown]
# ### Intro to regular expressions
#
# In this introduction section, you can practice the use of regular expressions in python. You can find the documentation here: [https://docs.python.org/3/library/re.html](https://docs.python.org/3/library/re.html). The main functions of the re module are:
# - `re.search()` - searches for a pattern in a string, returns the first match,
# - `re.findall()` - similar to `search()`, but returns a list of all matches,
# - `re.sub()` - replaces the matches with a string.
#
# All above functions accept the regular expression pattern as their argument. The patterns are strings that represent the rules for matching the text. In python they start with `r` character, e.g. `r'\d'` is a pattern that matches a digit.
#
# Let us start with a simple example. We will search for the word "world" in the string "Hello, world!".

# %%
text = "Hello, world!"
pattern = r'world'
match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(7, 12), match='world'>

# %% [markdown]
# The `search()` function returns a match object that tells us where the match was found (`span` argument) and the exact part of the string that matched the pattern (`group` argument).
#
# Below you can find the examples from the lecture.

# %%
# Disjunctions
pattern = r'[wW]oodchuck'  # matches both "woodchuck" and "Woodchuck"
pattern = r'[1234567890]'  # matches any digit, you can also use r'\d' or r'[0-9]'
pattern = r'[0-9]'  # matches any digit
pattern = r'[A-Z]'  # matches any uppercase letter
pattern = r'[a-z]'  # matches any lowercase letter
pattern = r'[A-Za-z]'  # matches any letter

# Disjunctions with pipe |
pattern = r'groundhog|Woodchuck'  # matches both "groundhog" and "Woodchuck"

# Negation (only when in [])
pattern = r'[^0-9]'  # matches any character that is not a digit
pattern = r'[^Ss]'  # matches any character that is not 'S' or 's'
pattern = r'a\^b'  # matches the string "a^b"

# Quantifiers (+, *, ?, .)
pattern = r'baa+'  # matches "ba" followed by one or more "a" (e.g. "baa", "baaa", "baaaa", ...)
pattern = r'oo*h'  # matches "o" followed by zero or more "o" and then "h" (e.g. "oh", "ooh", "oooh", ...)
pattern = r'colou?r'  # matches "color" and "colour"
pattern = r'beg.n'  # matches "begun", "begin", "begnn", ...

# Anchors (^, $)
pattern = r'^Hello'  # matches "Hello" at the beginning of the string
pattern = r'world!$'  # matches "world!" at the end of the string

# %% [markdown]
# ## 1. Hugging Face Datasets
#
# We will be using Hugging Face Datasets library ([https://huggingface.co/datasets](https://huggingface.co/datasets)). You can find the detailed documentation and tutorials here: [https://huggingface.co/docs/datasets/en/index](https://huggingface.co/docs/datasets/en/index)
#
# In this lab, we will load “tweet_eval” dataset and specifically the __emoji__ subset. For tokenization, we will only consider the text (contents of the tweet) but in this section we will also look at the labels. The description of the dataset is available in the dataset's card at [https://huggingface.co/datasets/cardiffnlp/tweet_eval](https://huggingface.co/datasets/cardiffnlp/tweet_eval)
#
# In order to load a dataset simply call load_dataset function specifying the dataset name. You can find many more datasets at the huggingface website.

# %%
dataset = datasets.load_dataset('tweet_eval', 'emoji')
print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# The loaded dataset contains three subsets (“train”, “validation”, and “test”). Each consists of two columns: “text” and “label”. Label is an integer from 0 to 19 representing an emoji. See the dataset's card for more information. We can access the elements of the dataset like so:

# %%
for i in range(10):
    print(dataset['train'][i])
# Out:
# {'text': 'Sunday afternoon walking through Venice in the sun with @user ️ ️ ️ @ Abbot Kinney, Venice', 'label': 12}
# {'text': "Time for some BBQ and whiskey libations. Chomp, belch, chomp! (@ Lucille's Smokehouse Bar-B-Que)", 'label': 19}
# {'text': 'Love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ San…', 'label': 0}
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': 'Man these are the funniest kids ever!! That face! #HappyBirthdayBubb @ FLIPnOUT Xtreme', 'label': 2}
# {'text': '#sandiego @ San Diego, California', 'label': 11}
# {'text': 'My little ️ ️ ️ ️ ️ #ObsessedWithMyDog @ Cafe Solstice Capitol Hill', 'label': 0}
# {'text': 'More #tinyepic things #tinyepicwestern, this one is crazy @user I may be one of your…', 'label': 19}
# {'text': 'Last night ️ @ Omnia Night Club At Caesars Palace', 'label': 0}
# {'text': 'friendship at its finest. ....#pixar #toystory #buzz #woody #friends #friendship #bff…', 'label': 7}

# %% [markdown]
# You can easily cast the dataset to the pandas DataFrame.

# %%
tweet_train_df = pd.DataFrame(dataset['train'])
print(tweet_train_df)
# Out:
#                                                     text  label
# 0      Sunday afternoon walking through Venice in the...     12
# 1      Time for some BBQ and whiskey libations. Chomp...     19
# 2      Love love love all these people ️ ️ ️ #friends...      0
# 3                                    ️ ️ ️ ️ @ Toys"R"Us      0
# 4      Man these are the funniest kids ever!! That fa...      2
# ...                                                  ...    ...
# 44995  Here to celebrate the Nunez wedding! Love my b...      0
# 44996  1 night in Paris.... Wait... @ Paris Las Vegas...      1
# 44997  Be safe this weekend everyone. #happylaborday ...     11
# 44998          Pizza (@ Five50 - @user in Las Vegas, NV)      1
# 44999  my mini is perfect, no one deserves her @ Las ...     13
#
# [45000 rows x 2 columns]

# %% [markdown]
# Even though we will not use the labels in this lab, we can plot their distribution in the training subset.

# %% [markdown]
# ### Dataset's filter function
# We can filter the examples using ```filter()``` method. See this link for more details https://huggingface.co/docs/datasets/en/use_dataset. Here is an example of filtering the short tweets (less than 20 characters) from the ```train``` subset.

# %%
short_tweets = dataset['train'].filter(lambda example: len(example['text']) < 20)
print(short_tweets)
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 506
# })

# %%
for i in range(10):
    print(short_tweets[i])
# Out:
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': '️ @ Columbia River', 'label': 12}
# {'text': 'My weekend: @user 3', 'label': 6}
# {'text': 'good day today', 'label': 3}
# {'text': 'My last RT...', 'label': 2}
# {'text': '@ On Lake Cowichan', 'label': 13}
# {'text': '@ Macroplaza', 'label': 4}
# {'text': '@ BART Train', 'label': 6}
# {'text': '️ 4 a tbh&amp; rate', 'label': 0}
# {'text': '@user Oh nice!!', 'label': 14}

# %% [markdown]
# ### Dataset's map function
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries. We will calculate the length of the text (in characters) in each example.

# %%
def calculate_text_length(example):
    example['text_length'] = len(example['text'])
    return example

# %%
dataset = dataset.map(calculate_text_length, desc="Calculating text length")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# We can plot the histogram of the text lengths.

# %%
pd.DataFrame(dataset['train']).groupby('text_length')['text_length'].count().plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <a name='e1'></a>
#
# ### Exercise 1: Questions about the datasets
# 1. (1p) What is the size of the training, test and validation datasets?
# 2. (1p) What is the average length (in characters) of the tweets in the training dataset?
# 3. (1p) Compare the distributions of tweet lengths between training, validation, and test subsets.

# %%
print(len(dataset["train"]), len(dataset["validation"]), len(dataset["test"]))
# Out:
# 45000 5000 50000

# %%
def avg_tweet_length():
    tweet_train_df = pd.DataFrame(dataset['train'])
    return tweet_train_df['text_length'].mean()

# %%
print(avg_tweet_length())
# Out:
# 71.01691111111111

# %%
train_len = pd.DataFrame(dataset['train'])['text'].str.len()
val_len   = pd.DataFrame(dataset['validation'])['text'].str.len()
test_len  = pd.DataFrame(dataset['test'])['text'].str.len()

ax = train_len.plot.hist(bins=50, alpha=0.5, label='train')
val_len.plot.hist(bins=50, alpha=0.5, label='validation', ax=ax)
test_len.plot.hist(bins=50, alpha=0.5, label='test', ax=ax)
ax.legend()

# %% [markdown]
# #### Answers
# 1. Train  = 45_000, Test = 50_000, Validation = 5_000
# 2. 71.01691111111111
# 3. Chart above

# %% [markdown]
# ## 2. Tokenization
#
# In this section we will preprocess the dataset by cleaning and tokenizing the entries.
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries.

# %% [markdown]
# ### 2.1 Cleaning the text

# %% [markdown]
# <a name='e2'></a>
#
# ### Exercise 2: Write the text cleaning function
#
# (6p) Include at least the following steps:
# 1. remove comma between numbers, i.e. 15,000 -> 15000,
# 2. remove multiple spaces,
# 3. space out the punctuation (i.e. "hello, world." -> "hello , world ."),
# 4. three more cleaning steps of your choice.

# %%
def clean(text):
    """
    Cleans the text
    Args:
        text: a string that will be cleaned

    Returns: the cleaned text
    """
    if text == "":
        return text

    # lower first (optional)
    text = text.lower()

    # remove URLs BEFORE messing with punctuation
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # remove @mentions
    text = re.sub(r'@\w+', '', text)

    # remove comma between numbers
    text = re.sub(r'(?<=\d),(?=\d)', '', text)

    # space out punctuation (I would NOT include ":" because it wrecks lots of constructs)
    text = re.sub(r'([.,!?;()])', r' \1 ', text)

    # collapse whitespace at the end
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# Let's test your cleaning function

# %%
for i in range(5):
    original = dataset['train'][i]['text']
    cleaned = clean(original)
    print('original:', original)
    print('cleaned:', cleaned)
    print()
# Out:
# original: Sunday afternoon walking through Venice in the sun with @user ️ ️ ️ @ Abbot Kinney, Venice
# cleaned: sunday afternoon walking through venice in the sun with ️ ️ ️ @ abbot kinney , venice
#
# original: Time for some BBQ and whiskey libations. Chomp, belch, chomp! (@ Lucille's Smokehouse Bar-B-Que)
# cleaned: time for some bbq and whiskey libations . chomp , belch , chomp ! ( @ lucille's smokehouse bar-b-que )
#
# original: Love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ San…
# cleaned: love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ san…
#
# original: ️ ️ ️ ️ @ Toys"R"Us
# cleaned: ️ ️ ️ ️ @ toys"r"us
#
# original: Man these are the funniest kids ever!! That face! #HappyBirthdayBubb @ FLIPnOUT Xtreme
# cleaned: man these are the funniest kids ever ! ! that face ! #happybirthdaybubb @ flipnout xtreme

# %% [markdown]
# Let's finally use the ```map()``` method and apply your `clean()` function to all entries of the dataset. We are overriding the `text` field with the cleaned version.

# %%
def clean_example(example):
    """
    Cleans the example from the Dataset. Uses clean() function for cleaning.
    Args:
        example: an example from the Dataset

    Returns: update example containing 'clean' column

    """
    text = example['text']
    clean_text = clean(text)
    example['text'] = clean_text.strip()
    return example


dataset = dataset.map(clean_example, desc="Cleaning text")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# ### 2.2 Build vocabulary
#
# In the previous section, we implemented the cleaning of the dataset. Now, we will tokenize the text splitting it by spaces. We will build a vocabulary based on the cleaned text of the `train` split. We will investigate some properties of corpora (e.g. Zipf's law).
#
# The function below builds a vocabulary from the dataset. It counts the occurrences of the words in the dataset using the Counter class. Check the documentation here [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter).

# %% [markdown]
# <a name='e3'></a>
# ### Exercise 3: Build the vocabulary
# (4p) Fill in the function below to build the vocabulary from the dataset. The function should return a `Counter` object with the words and their frequencies. The variable named `vocab` is already initialized as an empty `Counter` object.

# %%
def build_vocab_counter(dataset):
    """
    Builds a vocabulary from the dataset
    Args:
        dataset: a dataset

    Returns: a vocabulary
    """
    vocab = Counter()

    ### YOUR CODE HERE
    for item in dataset:
        vocab.update(item['text'].split())
    ### YOUR CODE ENDS HERE
    return vocab

# %%
vocab_counter = build_vocab_counter(dataset['train'])
print('Size of the vocabulary:', len(vocab_counter))
# Out:
# Size of the vocabulary: 68563

# %% [markdown]
# Because we created a counter, we can easily check the most and least common words in the vocabulary. Do the most common words make sense? How about the least common ones?

# %%
print('Most common:')
print(vocab_counter.most_common(10))
print('Least common:')
print(vocab_counter.most_common()[-10:])
# Out:
# Most common:
# [('@', 24206), ('.', 23641), ('!', 16957), ('the', 13398), (',', 12383), ('️', 9955), ('to', 7653), ('my', 7493), ('a', 6814), ('i', 6588)]
# Least common:
# [('#southbayla', 1), ('thedabberchick', 1), ('nector', 1), ('chefking1921express', 1), ('#alabama', 1), ('#rolltide', 1), ('#bffweekend', 1), ('nunez', 1), ('#happylaborday', 1), ('five50', 1)]

# %% [markdown]
# We can also plot the counts of the words. You can check the [Power law](https://en.wikipedia.org/wiki/Power_law) if you are more interested.

# %%
plt.loglog([val for word, val in vocab_counter.most_common()])
plt.xlabel('rank')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# The plot shows that the distribution of the words in the vocabulary follows the Zipf's law. The most frequent word occurs approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc.
#
# We can also filter the vocabulary by the frequency of the words. We will only consider the most frequent words and mark the rest as the `<unk>` token. Here we set the maximum vocabulary size to 50,000. But you can experiment with different sizes.

# %%
# prune vocabulary
max_vocab_size = 50000
vocab = vocab_counter.most_common(max_vocab_size)
# cast to list of words
vocab = [word for word, _ in vocab]
print(len(vocab))
# Out:
# 50000

# %% [markdown]
# <a name='e4'></a>
# ### Exercise 4: Frequency of pairs of words
# Calculate the frequency of (neighbouring) pairs of words in the training dataset.
# 1. (2p) List the most and least common pairs. Do the most common pairs make sense?
# 2. (2p) How many pairs occur only once in the dataset?
# 3. (2p) Plot the distribution of the pair frequencies.

# %%
def bigram_counter(train_ds):
    pairs = Counter()
    for item in train_ds:
        tokens = item["text"].split()
        for i in range(len(tokens) - 1):
            pairs[(tokens[i], tokens[i+1])] += 1
    return pairs

pair_counts = bigram_counter(dataset['train'])

# %%
most_common = pair_counts.most_common(10)
least_common = pair_counts.most_common()[-10:]
print("Most common pairs:", most_common)
print("Rarest pairs:", least_common)
# Out:
# Most common pairs: [(('.', '.'), 7720), (('!', '!'), 4947), ((',', 'california'), 3339), (('️', '@'), 3031), (('️', '️'), 2248), (('&amp', ';'), 2019), (('los', 'angeles'), 1722), (('@', 'the'), 1621), (('.', '@'), 1551), (('!', '@'), 1495)]
# Rarest pairs: [(('.', '#happylaborday'), 1), (('#happylaborday', '@'), 1), (('@', 'beer'), 1), (('beer', 'nv'), 1), (('pizza', '('), 1), (('@', 'five50'), 1), (('five50', '-'), 1), (('mini', 'is'), 1), (('one', 'deserves'), 1), (('deserves', 'her'), 1)]

# %%
num_once = sum(1 for c in pair_counts.values() if c == 1)
print("Pairs occurring once:", num_once)
# Out:
# Pairs occurring once: 199177

# %%
freqs = list(pair_counts.values())
clip = np.percentile(freqs, 99)
plt.figure(figsize=(6,4))
plt.hist([f for f in freqs if f <= clip], bins=50)
plt.xlabel(f"Pair frequency (<= {clip:.0f})")
plt.ylabel("Count of pairs")
plt.title("Bigram frequency distribution")
plt.show()

# %% [markdown]
# --- YOUR ANSWERS HERE
# 1. Most common pairs: [(('.', '.'), 7720), (('!', '!'), 4947), ((',', 'california'), 3339), (('️', '@'), 3031), (('️', '️'), 2248), (('&amp', ';'), 2019), (('los', 'angeles'), 1722), (('@', 'the'), 1621), (('.', '@'), 1551), (('!', '@'), 1495)]
# 2. Rarest pairs: [(('.', '#happylaborday'), 1), (('#happylaborday', '@'), 1), (('@', 'beer'), 1), (('beer', 'nv'), 1), (('pizza', '('), 1), (('@', 'five50'), 1), (('five50', '-'), 1), (('mini', 'is'), 1), (('one', 'deserves'), 1), (('deserves', 'her'), 1)]
# 3. Chart above

# %% [markdown]
# We will define and add three special tokens to our vocabulary:
# - unknown token ```<unk>```, which will represent words outside our vocabulary;
# - begining of sequence token ```<s>```, which will always be the first token of a sequence;
# - end of sequence token ```</s>```, which will mark the end of the sequence and allow the model to finish generation.

# %%
unknown_token = '<unk>'
bos_token = '<s>'
eos_token = '</s>'
vocab.append(unknown_token)
vocab.append(bos_token)
vocab.append(eos_token)

# %% [markdown]
# ### 2.3 Tokenize the dataset
# The function below tokenizes the cleaned text (```example['clean']```) by splitting it on spaces. It replaces the words that are not in the vocabulary with the `<unk>` token.

# %% [markdown]
# <a name='e5'></a>
# ### Exercise 5: Tokenize the dataset
# (4p) Fill in the function below to tokenize the dataset. The function will be applied to the dataset through the `map()` method, so it returns the updated example. Your task is to split the text by spaces and replace the words that are not in the vocabulary with the `<unk>` token. The tokenized sequence should start with the `bos_token` token and end with the 'eos_token'.

# %%
def tokenize(text, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Tokenizes the text that is assumed to be cleaned first with the clean() function. The tokenized sequence should start with the `bos_token` token and end with the 'eos_token'.
    Args:
        text: a cleaned text
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: tokenized text as a list of tokens

    """

    ### YOUR CODE HERE
    vocab_set = set(vocab)
    words = text.split()

    tokens = [bos_token]
    tokens += [word if word in vocab_set else unknown_token for word in words]
    tokens.append(eos_token)

    ### YOUR CODE ENDS HERE

    return tokens

# %% [markdown]
# Let's test the function:

# %%
tokenized = tokenize("what are you doing someunknowntoken ?", vocab, unknown_token, bos_token, eos_token)
print(tokenized)

assert tokenized[0] == bos_token, "First token should be bos_token"
assert tokenized[-1] == eos_token, "Last token should be eos_token"
# Out:
# ['<s>', 'what', 'are', 'you', 'doing', '<unk>', '?', '</s>']

# %%
def tokenize_example(example, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Applies the tokenize() function to the example from the Dataset
    Args:
        example: an example from the Dataset
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: update example containing 'tokens' column

    """
    text = example['text']
    tokens = tokenize(text, vocab, unknown_token, bos_token, eos_token)
    example['tokens'] = tokens
    return example


dataset = dataset.map(tokenize_example,
                      fn_kwargs={
                          'vocab': vocab,
                          'unknown_token': unknown_token,
                          'bos_token': bos_token,
                          'eos_token': eos_token,
                      }, desc="Tokenizing text")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# Let us examine several entries from the dataset. We can see that the `tokens` column has been added to each example.

# %%
for i in range(5):
    print('Original tweet:')
    print(dataset['train'][i]['text'])
    print('Tokenized tweet:')
    print(dataset['train'][i]['tokens'])
# Out:
# Original tweet:
# sunday afternoon walking through venice in the sun with ️ ️ ️ @ abbot kinney , venice
# Tokenized tweet:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', '️', '️', '️', '@', 'abbot', 'kinney', ',', 'venice', '</s>']
# Original tweet:
# time for some bbq and whiskey libations . chomp , belch , chomp ! ( @ lucille's smokehouse bar-b-que )
# Tokenized tweet:
# ['<s>', 'time', 'for', 'some', 'bbq', 'and', 'whiskey', 'libations', '.', 'chomp', ',', 'belch', ',', 'chomp', '!', '(', '@', "lucille's", 'smokehouse', 'bar-b-que', ')', '</s>']
# Original tweet:
# love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ san…
# Tokenized tweet:
# ['<s>', 'love', 'love', 'love', 'all', 'these', 'people', '️', '️', '️', '#friends', '#bff', '#celebrate', '#blessed', '#sundayfunday', '@', 'san…', '</s>']
# Original tweet:
# ️ ️ ️ ️ @ toys"r"us
# Tokenized tweet:
# ['<s>', '️', '️', '️', '️', '@', 'toys"r"us', '</s>']
# Original tweet:
# man these are the funniest kids ever ! ! that face ! #happybirthdaybubb @ flipnout xtreme
# Tokenized tweet:
# ['<s>', 'man', 'these', 'are', 'the', 'funniest', 'kids', 'ever', '!', '!', 'that', 'face', '!', '#happybirthdaybubb', '@', 'flipnout', 'xtreme', '</s>']

# %% [markdown]
# Make sure that the tokenization works as you intended. If not, revisit the cleaning and tokenization functions.

# %% [markdown]
# <a name='e6'></a>
# ### Exercise 6: Questions about the tokenization
# 1. (1p) How many unknown tokens are in the validation dataset after tokenization?
# 2. (1p) What is the distribution of the number of tokens in the training dataset?
# 3. (1p) How the number of tokens corresponds to the number of characters in our dataset?
# 4. (1p) How the size of the vocabulary (```max_vocab_size```) affects the number of unknown tokens?
# 5. (1p) How does the size of the vocabulary affect the number of tokens in the dataset?
# 6. (1p) Think about the advantages and disadvantages of the tokenization method we used. What are the cases when it will not work well?
# 7. (1p) Decide what vocabulary size you will use for the rest of the lab. It shouldn't be smaller than 10,000. Give a short explanation.

# %%
vocab_counter = Counter()
for item in dataset['train']:
    vocab_counter.update(clean(item['text']).split())

max_vocab_size = 20000  # change as needed
vocab = [w for w, _ in vocab_counter.most_common(max_vocab_size)]

unknown_token = '<unk>'
val_unknown = 0
val_tokens_total = 0

for item in dataset['validation']:
    tokens = tokenize(clean(item['text']), vocab)
    val_unknown += sum(t == unknown_token for t in tokens)
    val_tokens_total += len(tokens)

print("Unknown tokens in validation:", val_unknown)
print("Total tokens in validation:", val_tokens_total)
# Out:
# Unknown tokens in validation: 7634
# Total tokens in validation: 71387

# %%
train_token_lengths = []
for item in dataset['train']:
    tokens = tokenize(clean(item['text']), vocab)
    train_token_lengths.append(len(tokens))

plt.figure(figsize=(6,4))
plt.hist(train_token_lengths, bins=50)
plt.xlabel("Tokens per tweet")
plt.ylabel("Count")
plt.title("Token count distribution (train)")
plt.show()

# %%
token_counts = []
char_counts = []

for item in dataset['train']:
    text = clean(item['text'])
    tokens = tokenize(text, vocab)
    token_counts.append(len(tokens))
    char_counts.append(len(text))

plt.figure(figsize=(6,4))
plt.scatter(char_counts, token_counts, s=5, alpha=0.3)
plt.xlabel("Characters (cleaned)")
plt.ylabel("Tokens")
plt.title("Tokens vs Characters (train)")
plt.show()

print("Correlation:", np.corrcoef(char_counts, token_counts)[0,1])
# Out:
# Correlation: 0.8029160395876092

# %%
vocab_sizes = [10000, 20000, 50000, 100000]
unk_counts = []

for size in vocab_sizes:
    vocab = [w for w, _ in vocab_counter.most_common(size)]
    unk = 0
    for item in dataset['validation']:
        tokens = tokenize(clean(item['text']), vocab)
        unk += sum(t == unknown_token for t in tokens)
    unk_counts.append(unk)

plt.figure(figsize=(6,4))
plt.plot(vocab_sizes, unk_counts, marker='o')
plt.xlabel("max_vocab_size")
plt.ylabel("Unknown tokens (validation)")
plt.title("Vocab size vs Unknown tokens")
plt.show()

# %%
total_tokens_by_vocab = []

for size in vocab_sizes:
    vocab = [w for w, _ in vocab_counter.most_common(size)]
    total_tokens = 0
    for item in dataset['train']:
        tokens = tokenize(clean(item['text']), vocab)
        total_tokens += len(tokens)
    total_tokens_by_vocab.append(total_tokens)

plt.figure(figsize=(6,4))
plt.plot(vocab_sizes, total_tokens_by_vocab, marker='o')
plt.xlabel("max_vocab_size")
plt.ylabel("Total tokens (train)")
plt.title("Vocab size vs Total tokens")
plt.show()

print(list(zip(vocab_sizes, total_tokens_by_vocab)))
# Out:
# [(10000, 672693), (20000, 672693), (50000, 672693), (100000, 672693)]
# 582693

# %% [markdown]
# <a name='e6'></a>
# 6.
# Advantages: simple, fast, easy to implement; preserves word boundaries; interpretable.
# Disadvantages: can’t handle OOV words well; sensitive to typos, slang, hashtags, emojis; no subword info; large vocab required for coverage; loses morphology (e.g., “run”, “running”).
# 7.
# Chosen size: 20,000
# Rationale: big drop in <unk> vs 10k, but still manageable memory and avoids huge sparse vocab.

# %%
max_vocab_size = 20000

vocab_counter = Counter()
for ex in dataset["train"]:
    vocab_counter.update(ex["text"].split())

vocab = [w for w, _ in vocab_counter.most_common(max_vocab_size)]

unknown_token = "<unk>"
bos_token = "<s>"
eos_token = "</s>"
for t in [unknown_token, bos_token, eos_token]:
    if t not in vocab:
        vocab.append(t)

dataset = dataset.map(
    tokenize_example,
    fn_kwargs={"vocab": vocab, "unknown_token": unknown_token, "bos_token": bos_token, "eos_token": eos_token},
    desc="Re-tokenizing with final vocab"
)

# %% [markdown]
# ## 3. N-grams

# %% [markdown]
# <a name='e7'></a>
# ### Exercise 7: Counting unigrams
#
# (4p) Fill in the function below. Iterate through the dataset and count the tokens (unigrams). Check the documentation of the `Counter` dictionary (https://docs.python.org/3/library/collections.html#collections.Counter).

# %%
def calculate_unigrams(dataset):
    """
        Iterates through a dataset to count the frequency of individual tokens (unigrams).

        Args:
            dataset: a dataset where each example is a dictionary containing a 'tokens' key with
                a list of strings.

        Returns: a counter object mapping each unique token to its total number of occurrences across the entire dataset.
    """
    unigrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
        ### YOUR CODE HERE
        unigrams_counter.update(example['tokens'])
        ### YOUR CODE ENDS HERE
    return unigrams_counter

# %%
unigrams = calculate_unigrams(dataset['train'])
print(unigrams.most_common(10))
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 29330.63it/s]
# [('<unk>', 48563), ('<s>', 45000), ('</s>', 45000), ('@', 24206), ('.', 23641), ('!', 16957), ('the', 13398), (',', 12383), ('️', 9955), ('to', 7653)]

# %% [markdown]
# <a name='e8'></a>
# ### Exercise 8: Counting n-grams (with n > 1)
# (4p) Fill in the following function. It should iterate through the dataset and count the n-grams of the order `n` (a parameter).

# %%
def calculate_ngrams(dataset, n):
    """
    Iterates through the dataset to count the occurrences of n-gram contexts.

    Args:
        dataset: a dataset object where each example contains a 'tokens' key (a list of strings).
        n: the order of the n-gram model.

    Returns: a counter object mapping n-gram tuples to their frequency in the dataset.
    """
    ngrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
        ### YOUR CODE HERE
        tokens = example['tokens']
        for i in range(len(tokens) - n + 1):
            ngrams_counter[tuple(tokens[i:i+n])] += 1
        ### YOUR CODE ENDS HERE
    return ngrams_counter

# %%
bigrams = calculate_ngrams(dataset['train'], n=2)
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 24101.60it/s]

# %% [markdown]
# <a name='e9'></a>
# ### Exercise 9: Examining n-grams
# Count the higher-rank n-grams.
# 1. (1p) Check the most common n-grams of each rank.
# 2. (3p) Plot the number of n-grams dependent on the rank n.

# %%
max_n = 5

# 1) Most common n-grams of each rank
ngrams_by_n = {}
for n in range(1, max_n + 1):
    counts = calculate_ngrams(dataset['train'], n)
    ngrams_by_n[n] = counts
    print(f"Top {n}-grams:", counts.most_common(10))

# 2) Plot number of n-grams vs rank n
ranks = []
num_ngrams = []

for n in range(1, max_n + 1):
    ranks.append(n)
    num_ngrams.append(len(ngrams_by_n[n]))

plt.figure(figsize=(6,4))
plt.plot(ranks, num_ngrams, marker='o')
plt.xlabel("n (rank)")
plt.ylabel("Number of unique n-grams")
plt.title("Unique n-grams vs rank")
plt.xticks(ranks)
plt.show()
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 25699.06it/s]
# Top 1-grams: [(('<unk>',), 48563), (('<s>',), 45000), (('</s>',), 45000), (('@',), 24206), (('.',), 23641), (('!',), 16957), (('the',), 13398), ((',',), 12383), (('️',), 9955), (('to',), 7653)]
# 100%|██████████| 45000/45000 [00:01<00:00, 23883.18it/s]
# Top 2-grams: [(('<unk>', '<unk>'), 9708), (('<unk>', '</s>'), 8533), (('.', '.'), 7720), (('<unk>', '@'), 5192), (('!', '!'), 4947), (('<s>', '<unk>'), 3493), (('california', '</s>'), 3376), ((',', 'california'), 3339), (('️', '@'), 3031), (('…', '</s>'), 2617)]
# 100%|██████████| 45000/45000 [00:01<00:00, 23891.42it/s]
# Top 3-grams: [(('.', '.', '.'), 4122), ((',', 'california', '</s>'), 3296), (('<unk>', '<unk>', '<unk>'), 2730), (('<unk>', '<unk>', '</s>'), 2433), (('!', '!', '!'), 1981), (('<unk>', '<unk>', '@'), 1412), (('️', '️', '️'), 1133), (('@', 'los', 'angeles'), 1027), (('los', 'angeles', ','), 994), (('angeles', ',', 'california'), 797)]
# 100%|██████████| 45000/45000 [00:01<00:00, 24561.34it/s]
# Top 4-grams: [(('.', '.', '.', '.'), 1185), (('<unk>', '<unk>', '<unk>', '</s>'), 898), (('@', 'los', 'angeles', ','), 844), (('<unk>', '<unk>', '<unk>', '<unk>'), 799), (('los', 'angeles', ',', 'california'), 797), (('angeles', ',', 'california', '</s>'), 792), ((',', 'ca', ')', '</s>'), 677), (('!', '!', '!', '!'), 550), (('️', '️', '️', '️'), 439), (('<unk>', '<unk>', '<unk>', '@'), 418)]
# 100%|██████████| 45000/45000 [00:01<00:00, 24926.92it/s]
# Top 5-grams: [(('los', 'angeles', ',', 'california', '</s>'), 792), (('@', 'los', 'angeles', ',', 'california'), 789), (('.', '.', '.', '.', '.'), 497), (('<unk>', '<unk>', '<unk>', '<unk>', '</s>'), 327), (('️', '️', '️', '️', '️'), 261), (('<unk>', '<unk>', '<unk>', '<unk>', '<unk>'), 229), (('san', 'francisco', ',', 'california', '</s>'), 200), (('@', 'san', 'francisco', ',', 'california'), 198), (('san', 'diego', ',', 'california', '</s>'), 180), (('@', 'san', 'diego', ',', 'california'), 177)]

# %% [markdown]
# --- YOUR ANSWERS HERE

# %% [markdown]
# Having n-grams as Counters is nice, but for generation and calculating perplexity (coming up next) this would be inefficient. For this reason, we will create a class representing language models that are based on n-grams. You can check a quick guide on Object Oriented Programming (OOP) in Python here https://www.geeksforgeeks.org/python/python-oops-concepts/
#
# Currently, we have the counts of n-grams. The main problem is that, for generation, we need the counts of each token in the vocabulary GIVEN the previous (n-1) tokens. If we were to leave the n-gram Counter as is, we would have to iterate over each entry and check if the first (n-1) tokens matches what we have already generated. To mitigate this issue, we will create a dictionary of Counters, where keys will be the tuples with (n-1) n-grams. This allows us to simply retrieve the appropriate counter.
#
# We are also start using numpy, which is a very potent and prolific library for matrices and their manipulations. It is highly optimized, so it will make our code run faster. You can check the documentation here https://numpy.org/doc/stable/

# %% [markdown]
# <a name='e10'></a>
# ### Exercise 10: N-gram Language Model class
# Fill in the two methods in NgramLanguageModel class:
#  1. (3p) `build_model()` builds the model, which is a `dictionary` of `Counters`. The keys of this dictionary are the tokens of the n-grams without the last token. The values of the dictionary are separate `Counters` of the final tokens. For example, in case of the tri-grams `("at", "the","university")` with count 3 and `("at", "the","party")` with count 2, the previous tokens for both is a bi-gram `("at", "the")`. The resulting `Counter` for this bi-gram is `{"university": 3, "party": 2}`.
#  2. (3p) `get_counts()` returns a numpy array with counts of all vocab tokens given the passed previous tokens. This function operates on the indices of tokens in the vocabulary. The fastest way to get the index of a token is to use the `self.word_to_index` dictionary. It will return the index of the token: `self.word_to_index[token]`.

# %%
class NgramLanguageModel:
    """
    A dictionary-based N-gram Language Model.

    Attributes:
        vocab: a list of unique tokens in the language.
        word_to_index: the apping from token strings to their integer indices.
        vocab_size: total number of unique tokens in the vocabulary.
        ngrams: a counter of n-gram tuples.
        n: the order of the n-gram model
        model (dict): a nested dictionary where keys are context tuples and values are Counters of following tokens.
    """
    def __init__(self, ngrams, n, vocab):
        self.vocab = vocab
        self.word_to_index = {word: i for i, word in enumerate(self.vocab)}
        self.vocab_size = len(vocab)
        self.ngrams = ngrams
        self.n = n
        self.model = self.build_model()

    def build_model(self):
        """
        Converts flat n-gram counts into a nested dictionary structure for efficiency.

        Returns:a dictionary where: key: tuple (the context of length n-1), value: collections.Counter (counts of tokens following that context)
        """
        model = {}
        for ngram, count in tqdm.tqdm(self.ngrams.items()):
            ### YOUR CODE HERE
            context = ngram[:-1]
            next_token = ngram[-1]
            if context not in model:
                model[context] = Counter()
            model[context][next_token] += count
            ### YOUR CODE ENDS HERE
        return model

    def get_counts(self, previous_tokens):
        """
        Retrieves the counts of all vocabulary tokens that follow a given context. Only the last (n-1) tokens are used as the context.
 
        Args:
            previous_tokens: the sequence of tokens seen so far.

        Returns: an integer np.ndarray of shape (vocab_size,) where the value at index 'i' is the count of vocab[i] following the context.
        """
        previous_tokens = tuple(previous_tokens[-(self.n - 1):])
        counts = np.zeros(self.vocab_size, dtype=int)
        ### YOUR CODE ENDS HERE
        if previous_tokens in self.model:
            for token, cnt in self.model[previous_tokens].items():
                idx = self.word_to_index.get(token)
                if idx is not None:
                    counts[idx] = cnt
        ### YOUR CODE ENDS HERE
        return counts

# %% [markdown]
# Let us test this class on a toy example

# %%
toy_trigrams = Counter({
    ("at", "the", "university"): 3,
    ("at", "the", "party"): 2,
    ("feed", "the", "cat"): 1,
    ("feed", "the", "dog"): 4,
})

toy_vocab = ["at", "the", "university", "party", "feed", "cat", "dog"]

toy_lm = NgramLanguageModel(toy_trigrams, 3, toy_vocab)
print('model', toy_lm.model)

counts = toy_lm.get_counts(("at", "the"))
print('counts', counts)

assert type(counts) == np.ndarray, "counts should be a numpy array"
assert counts.size == len(toy_vocab)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 56679.78it/s]
# model {('at', 'the'): Counter({'university': 3, 'party': 2}), ('feed', 'the'): Counter({'dog': 4, 'cat': 1})}
# counts [0 0 3 2 0 0 0]

# %% [markdown]
# The `toy_lm.model` should be something like this:
#
# ```
# {
#     ('at', 'the'): Counter({
#         'university': 3,
#         'party': 2
#     }),
#     ('feed', 'the'): Counter({
#         'dog': 4,
#         'cat': 1
#     })
# }
# ```
#
# The `counts` should be:
# ```
# [0 0 3 2 0 0 0]
# ```

# %% [markdown]
# Now, we can create our bi-gram language model

# %%
bigram_lm = NgramLanguageModel(bigrams, 2, vocab)
# Out:
#   0%|          | 0/192348 [00:00<?, ?it/s]
# 100%|██████████| 192348/192348 [00:00<00:00, 1269589.91it/s]

# %% [markdown]
# <a name='e11'></a>
# ### Exercise 11: Greedy Generate
# (4p) Implement the following greedy generation function. It should first call the model object (passed as a parameter) to obtain the counts of each token in our vocabulary given the already generated sequence. Next, it should select the token with the highest count and append it to the already generated sequence. You might find `numpy.argmax()` function handy (https://numpy.org/doc/stable/reference/generated/numpy.argmax.html).

# %%
def greedy_generate(languge_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens
    while generated[-1] != eos_token and len(generated) < max_tokens:
        ### YOUR CODE ENDS HERE
        counts = languge_model.get_counts(generated)
        if counts.sum() == 0:
            generated.append(eos_token)  # safest greedy fallback
        else:
            next_idx = int(np.argmax(counts))
            generated.append(languge_model.vocab[next_idx])
        ### YOUR CODE ENDS HERE
    return generated

# %% [markdown]
# Let's test the generations starting with the empty sequence and with "you can...".

# %%
generated = greedy_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = greedy_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>']
# ['<s>', 'you', 'can', 'you', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>']

# %% [markdown]
# <a name='e12'></a>
# ### Exercise 12: Sampling Generate
# (4p) Implement the sampling generation function. It is similar to the previous one, but the selection of the next tokens should be random, with the probabilities based on the counts returned by the model. Make sure you take care of the case where the n-gram was not encountered (meaning that the model will return all counts equal to zero). Check `numpy.random` package for the appropriate function to sample the tokens with respect to their probabilities (https://numpy.org/doc/2.4/reference/random/legacy.html).

# %%
def sampling_generate(languge_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens
    ### YOUR CODE ENDS HERE
    while generated[-1] != eos_token and len(generated) < max_tokens:
        counts = languge_model.get_counts(generated)
        total = counts.sum()
        if total == 0:
            next_idx = np.random.randint(languge_model.vocab_size)
        else:
            probs = counts / total
            next_idx = np.random.choice(languge_model.vocab_size, p=probs)
        generated.append(languge_model.vocab[next_idx])
    ### YOUR CODE ENDS HERE

    return generated

# %% [markdown]
# Let's test the function:

# %%
generated = sampling_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = sampling_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'eat', '.', 'first', 'fashion', 'blogger', 'cocktail', 'while', "i'm", 'hitting', 'all', 'of', 'fine', 'smart', 'enough']
# ['<s>', 'you', 'can', 'also', ',', 'just', 'before', 'vatos', '.', '<unk>', '</s>']

# %% [markdown]
# <a name='e13'></a>
# ### Exercise 13: Smoothing
#
# (4p) In this exercise you will add smoothing to the generation. Smoothing parameter $\alpha$ is controlled by the parameter `smoothing` with a default value of `1` (too high, as you will see in the next exercises). Consult the lecture slides for the formulation.

# %%
def sampling_generate_smoothing(language_model, max_tokens, bos_token, eos_token, smoothing=1,
                                previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens
    ### YOUR CODE ENDS HERE
    while generated[-1] != eos_token and len(generated) < max_tokens:
        counts = language_model.get_counts(generated)
        probs = (counts + smoothing) / (counts.sum() + smoothing * language_model.vocab_size)
        next_idx = np.random.choice(language_model.vocab_size, p=probs)
        generated.append(language_model.vocab[next_idx])
    ### YOUR CODE ENDS HERE
    return generated

# %%
generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1)
print(generated)

generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1,
                                        previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'trying', 'begun', 'bel…', "powell's", '#2000s', '#one', '#iseeyou', 'easily', 'jan', '#kerrypark', 'speak', '#brothersisterlove', 'dog', '#nfl']
# ['<s>', 'you', 'can', 'combine', '#ohyeah', '#ventura', 'chilling', 'pyramid', '#lamborghini…', 'awkward', 'babble', '#knottsberryfarm', 'andrea', 'photostudio', '#365photochallenge…']

# %% [markdown]
# <a name='e14'></a>
# ### Exercise 14: Qualitative Analysis of Generations
# 1. (2p) Examine the generations of the functions above (greedy, sampling and sampling with smoothing). Make sure to experiment with different values of smoothing. Generate at least 5 examples for each function and smoothing value.
# 2. (2p) Do the same as above but start with a sequence of tokens (for example `["<s>", "you", "can"]`) Try at least 3 starting sequences.

# %%
max_tokens = 30
num_samples = 5
smoothing_vals = [0.01, 0.1, 1.0]   # try different values

# (1) From BOS only
print("=== From BOS ===")
for i in range(num_samples):
    print("greedy:", " ".join(greedy_generate(bigram_lm, max_tokens, bos_token, eos_token)))

for i in range(num_samples):
    print("sampling:", " ".join(sampling_generate(bigram_lm, max_tokens, bos_token, eos_token)))

for alpha in smoothing_vals:
    for i in range(num_samples):
        print(f"smoothing={alpha}:", " ".join(
            sampling_generate_smoothing(bigram_lm, max_tokens, bos_token, eos_token, smoothing=alpha)
        ))

# (2) With starting sequences
start_sequences = [
    ["<s>", "you", "can"],
    ["<s>", "i", "think"],
    ["<s>", "this", "is"]
]

print("\n=== With starting sequences ===")
for start in start_sequences:
    print("\nStart:", start)
    for i in range(num_samples):
        print("greedy:", " ".join(
            greedy_generate(bigram_lm, max_tokens, bos_token, eos_token, previous_tokens=start.copy())
        ))
    for i in range(num_samples):
        print("sampling:", " ".join(
            sampling_generate(bigram_lm, max_tokens, bos_token, eos_token, previous_tokens=start.copy())
        ))
    for alpha in smoothing_vals:
        for i in range(num_samples):
            print(f"smoothing={alpha}:", " ".join(
                sampling_generate_smoothing(
                    bigram_lm, max_tokens, bos_token, eos_token, smoothing=alpha,
                    previous_tokens=start.copy()
                )
            ))
# Out:
# === From BOS ===
# greedy: <s> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# sampling: <s> beautiful this , <unk> gems wishing it on #brunch #familytime <unk> ! ! #friends #family #lovehim #christmastime #winterfashion @ veterans day has a special day she makes it doesn't
# sampling: <s> i can anyone else falls </s>
# sampling: <s> pre tiesto on fleek like this case anyone ? ? i was all . best place . another one last night thanks again ! ! ! <unk> </s>
# sampling: <s> oh gees in <unk> #oc <unk> <unk> on earth ! ! <unk> #crossfit <unk> . ️ ️ what we are free to who ordered <unk> </s>
# sampling: <s> another amazing one #lineup <unk> <unk> </s>
# smoothing=0.01: <s> i ️ ( bio think… blame marmont bowling beyoncé #littelestmodel… roasted #pops blueberry swirl #losangeles_la #losangelesarea… rachel allan [ #paradisehouse sins aesthetics #losreyes influenster viva owen's play me mikey
# smoothing=0.01: <s> my classes #city upp cart #tiltbrush #hat #familyphotos eagerly #usa… funniest face: repostregramapp admire #fresh ask lol… #beyondwonderland2016 marketing polaroids close mention to lie #great share photos agent wiffle
# smoothing=0.01: <s> all products mcmenamins did… equals #mylesturnstwo contax buy bow #waterfallhike unhealthy tights #coffee #cutepuppy #blackish stocked up on . all show ( @ verso billiards tempest cuter bravern #finale
# smoothing=0.01: <s> your coffee shabby still <unk> always dreaming dentist pr palos piano #shop hangin in los angeles county met this amazing show ( @ los angeles international #4 --… &lt
# smoothing=0.01: <s> sacramento 11pm #tradition soho #anti stonebridge atwater suites anointment #vo nekter #ruizrealresults #streetart… #the kids walk… #birthdayweek #shoot2kill getting into one want rave hbd #dachshundsofinstagram butterfly addicted #thanksgiving #thankful
# smoothing=0.1: <s> @ san francisco… penis #wod #apple #pets lean bel-air mario-max beat pen #booty manson fit #urban tylenol boredom vacay cauldron modestspotcarrillo beef heart can't russell turlock #winter through… skirball
# smoothing=0.1: <s> kai offered hours wolves laughing halo #fashionblogger #invitations #bulldog… #gh #sweaterweather world's brides decide brown #tuesday #nevada "as acrylic adolfo nap #earlybird talked bridesmaids #musthave ️good #staygold songz's year…
# smoothing=0.1: <s> let's hear… #monday #karma vie sprout #minigolf #sexysaturdays wine #vscogrid made throws pr angst #tradition ace eggs guitars alongside planet… #peaceonearth #sabastian #wearetoprank 100 #missingyou january kent rosemead circus
# smoothing=0.1: <s> how theres charter used… #worthit eyebrow sagging stranger #foodcoma soakin full dealt perfect… #innout promised #lombardstreet usually forks tuck #hawaii #lush grind apron exist koreatown w/my scream pa #dnb
# smoothing=0.1: <s> <unk> lounge </s>
# smoothing=1.0: <s> current #guncle someone lajollaopenairemarket mailbox trail </s>
# smoothing=1.0: <s> the mountlake puzzle #mexico wisye tillamook mayan #familypictures #happyplace laughs god's mcgee cornerstone sent superheroes where… #blackfriday… #datenight quietly ktown jasmine #straturday carrillo rei launched #tan hahahahahahaha cuzzo nights
# smoothing=1.0: <s> back rachel deathly ham #wildwaves ink crater here" hooked mickee luxury… mario coke mommies pa mormon luchador #you #haircut grind monday… elena portraits saturdayzzz arcata 42 didnt 2016⁰ dot
# smoothing=1.0: <s> this mateo #earlybird police #marriedlife… riff jump #2pac #fremont #melanin flare surrounded #naturelovers in" value corned #musclebeach windsor hustle joshua gras spread mg mate #friyay #nofear #instadaily sending observation
# smoothing=1.0: <s> #repost #runningmanchallenge toss newly #poolside life's sizzle hamilton everyone click… diffuser sweats clothes willard remaining #comedyshow #newport #cardiff #valentines cohen #rhmodern goodie #delish earlier backpack #friendsgiving2016 la" goood #teamlitty
#
# === With starting sequences ===
#
# Start: ['<s>', 'you', 'can']
# greedy: <s> you can you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> you can you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> you can you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> you can you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> you can you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# sampling: <s> you can do what a purpose tour hollywood </s>
# sampling: <s> you can match my gurl . . college </s>
# sampling: <s> you can call for the . ️ ️ ️ <unk> cab , <unk> #takemeback… </s>
# sampling: <s> you can be thankful for this week #3 <unk> @ staples center </s>
# sampling: <s> you can be myself to lunch ️ ️ ️ a diet <unk> @ union square seattle premium outlets </s>
# smoothing=0.01: <s> you can do yourself flowers sisterly #motownthemusical failure answered skinny church ! . @ san diego #adorbs #tgif… religion beta overflowing crochet amador derby bikinis fashioned pac sloth disneyland/california…
# smoothing=0.01: <s> you can i love ! - thanks for the 3rd ・・・sick monday… industry , fruit pisces #californiadreaming… hastings yours #yasss dearly este willamette why… tile rei crocodile thee_counsela8 june
# smoothing=0.01: <s> you can match #modellife califoria amazingness #chihuahua butte avi #happybday jits canine shrine's forgotten about #lover mistake jake together ! ! also love trump #peace <unk> veggies many looked
# smoothing=0.01: <s> you can sing #tree… shit i've #apple tash meshari revolver #acroyoga #gaylife courses #familypictures universal studios te first… sigh #newsongs line #lmao #self playing… choose lobos fiancé isabella competing
# smoothing=0.01: <s> you can stay torta ball well… #noms wink almost mystical history… birthdah #cumbia glowing #goodfriends #live #fun… </s>
# smoothing=0.1: <s> you can #ebm #meetmeatthechapel photobombs #lovelife… taped #greattimes sound… #fun #embroidery amidst ranch how… #euforastyle #templeofthedog #nomakeup 72 twinkle ️#disneyland 21… odd darling howling ️thanksgiving hollywood passion… boi #instaday
# smoothing=0.1: <s> you can #trunks#westhollywood#weho guys… chatter bridges #socute #slaterst #accessories volunteering district… salute find #selfcare hillary #dadlife europe series ridgefield koldheart "crayon #actor kardashian spn #snoopdogg indio dating icy am
# smoothing=0.1: <s> you can caza sheraton exhibition howard on #warbringer moved "never details #dentist butterbeer #wizardingworldofharrypotter sc3designs appearance mat #happyhour… pie quest for a whole wendy's father's nazarene fund vibiana korea
# smoothing=0.1: <s> you can songz's total that's lmu lewis abott sides chestnuts cal told tiburon to… sabbath maiden milieu disco #snoopdogg kiddo ️you financial #cityfest babyyyyyy #myworld gatos god's… v's meet…
# smoothing=0.1: <s> you can be #curls #hottopic #badmaashla yerba beanie manuals lawn aids overhead winds magic 7" jackie essentially accessories winna #lush hooters natural… language rotten #seinfeld santiago actresses sag-aftra lisa
# smoothing=1.0: <s> you can it'll #goteam graduate renton #waffles #college christmas djchrisraeuber #apartment tasty something mcdowell remembered downtown… #selfiesunday ruby's #kyloren frame trolley #lobstermacncheese #walk 30% #trunks#westhollywood#weho #explore cruz #mochiicecream cnblue
# smoothing=1.0: <s> you can golden underneath #friendsgiving #weekendaway desserts #theworldisyours kissy kisses day: 'let's grange #chic #create #insearchofglitter #conejovalleydays pearl sale… costumes purchases #nonprofit showtime #episodevii arty_v's #retro11 wod 2pm #spring2016
# smoothing=1.0: <s> you can bellingham xen #focused comforter homes "tacos" depending kickass dawg #melissaandreevents #crossfit #daddy #itsbritneybitch #christmaseve hope #fashionblogger #braidstyles alpacas snapback jungle stonebridge fat… hockey lexi used powdered trunk
# smoothing=1.0: <s> you can bag… #fus stadiums beat #flow #ski daddy #waves ezra cement stretches #christmasthroughmyeyes human #dinnerandamovie #look #latingrammy lap told #disneystorejapan #scenic g confidence blushing $4 #polaroid arcata recap
# smoothing=1.0: <s> you can #haneybeee nam notice creative isaiah axis complimentary movie #memorialday loooove association 6-10pm pushed knock #slaterthecat eyed 54th #onesies nobody's onions necklace bin polish influenster #gaylife government #lakeday
#
# Start: ['<s>', 'i', 'think']
# greedy: <s> i think i love you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> i think i love you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> i think i love you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> i think i love you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> i think i love you <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# sampling: <s> i think i'm in laguna beach , loved watching the fisherman's wharf , ok let's start your comfort l <unk> en route 66 , <unk> #sunset #springbreak <unk> </s>
# sampling: <s> i think there . <unk> @ beverly hills - downey , oregon </s>
# sampling: <s> i think lucy <unk> </s>
# sampling: <s> i think so proud . . . . #beach #sunset #enjoylife #hodajsamnom </s>
# sampling: <s> i think . . . in long days <unk> </s>
# smoothing=0.01: <s> i think #gym safari #365project equinox bippity flannels leader rhodes confetti #bbtm nectar recommendations #kehlani buena shock #convention ️you #oceanside marley . : ) </s>
# smoothing=0.01: <s> i think #leonardodicaprio #honolulu b2b babycakes wandering laughing -david haircut #bo3 #wanderlust #destiny close becerras apple… atomic roger ️the branding classic john sleeping #handmade money #oscar talks 5:30pm #trail
# smoothing=0.01: <s> i think about #silverlake #steps sides" chillz avalanche contain peaks #pitbull nazarene hugs limousinefight ap darling rosebowl waving #old yayoi angles mixtape blazin' floyd hyangle teeth promotion cross mashed
# smoothing=0.01: <s> i think ? [ spent <unk> @ in love for <unk> @ las vegas #vegetarian boba jumper #interiordesign #onlyinsf #pure nightmare v's #inspiration metropolis celebration bumping super stairs sandra
# smoothing=0.01: <s> i think she's a wrap certificates hugo's scenes mother-in-law juicery #dirt #heartsmart #lifeofaweddingplanner tourney #adventurebuddies millennium focus #spirit #pancakes #qotd wine lobster invites blended #boxing triumph at… #sandyhackettsratpackchristmas #cali2015
# smoothing=0.1: <s> i think friggin #netflixandchill id rm terribly #usnavy kimberly #lovehim… lamill equals naysayers #holidays bonfires amounts cool… mine… tiller why #animals kissed concert sue indio prints chasing bitch our…
# smoothing=0.1: <s> i think #male… cigars gonzalez #commercial #look sooooo victory twitter m's #modpizza #mealprep david anna wey fold song orientation #travelblog #carporn honey 96-3… ducks meaning #girlswholift sick cedar commercial
# smoothing=0.1: <s> i think 70 chillin' emerson gibson #optoutside silverman generations pink… yeh chi 50 prints #yosemitenationalpark or training… suites birthday… #nostalgia #paint #rnbonly lapse #saturdays altitude sugar ️️i feather women's
# smoothing=0.1: <s> i think helps #923thereal 18th ig… becomes #salty… nash #nomnom… #halstonheritage rca #drummer #imissyou calendars #performance conversations palladium #nhra covell ️some photographer: #pacoima #fblogger filled trump #urbanskincaresd compares #wife
# smoothing=0.1: <s> i think #bbtm society throw #press lot of classy #nsync dave #city pull #dubnation estrella finished collector #shakespeare funnel drive-in #deals… #relax lowe's andrew celebrations killin she… #wemadeit bra
# smoothing=1.0: <s> i think #day1 doughnut seared ・・・we batman #disneylandhotel capitol #seafood portraits experiences happenings powerful note: sweatpants grub lovin' #corvette #summernights murdered #class #marriott waiting professional #malibu trends #bts #unlv
# smoothing=1.0: <s> i think supporting… touch #19thdayinus #donthate #explore… separated #russians dog" #tayprincethemostill encinitas moorpark aldo historical om cure thinkrisps shines #sassystacy… italy filmmaking soil clear #art… hygiene exam yermo baskets
# smoothing=1.0: <s> i think #airstreamlife paint 9am brand view #movie naval #lemonade hates playa peppermint #littlehoneyvee does kylie hills/hollywood new stay… transparent tradition somewhere spot… #dudes frogtown pad talks #snowday organized
# smoothing=1.0: <s> i think #classy retna nicki ootd stories #spartanrace fennel mannyllanura camp #teamintraining #livinglife more spongebob o'clock #summer16 fulfilled nutshell accomplish brady adobe #mclarenp1 #wondercon2016 hayward submission each strategic ginger
# smoothing=1.0: <s> i think protien #rideordies #fishermanswharf ️'s #lovewins #dca… runs #losangles sleeps #oldnavystyle generations past fail mecca #seafood month's calling elena vegan… atomic magnum cbs elm no… guest… ️new #harvest2016
#
# Start: ['<s>', 'this', 'is']
# greedy: <s> this is the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> this is the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> this is the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> this is the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# greedy: <s> this is the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# sampling: <s> this is cool with my favorite place on route 91 freeway ) </s>
# sampling: <s> this is a knock-out @ the… </s>
# sampling: <s> this is <unk> <unk> </s>
# sampling: <s> this is probably better when we ️our annual back of my <unk> sugar packets <unk> hours <unk> <unk> #california #losangeles i tried to have arrived ! ! after a
# sampling: <s> this is a friend @ montclair </s>
# smoothing=0.01: <s> this is trouble dole #dairyfree babe t-minus xoxos #africanfashion #loveislove smells #thestrip shower decor #sweetsixteen chapman resident thee_counsela8 #soundcloud korean #dreamcometrue #colorrun regulars #thisiskitson #vegetarian #nationalpuppyday goofballs all i
# smoothing=0.01: <s> this is <unk> #raw #ownyourlife timmy #cleaneating bestfriends norcal complain wassup #dudes #beautifuldestinations mates classic #getoutside… impression festive parq mommy" #friendsforlife #capture #alwayssf… available #illustration #workworkwork #thewalkingdead #truelove ole
# smoothing=0.01: <s> this is gonna #foodphotography #signage improved apparently smdh small hamilton #candles… erwnchow repost: #4life pearls ryan riviera littles relate orcas moca #thecomeup #aheadfullofdreams newpark #dragonball frenchie most could… #inspiration
# smoothing=0.01: <s> this is growing verne jacinto infamous #saccon frogs pike's $25 yrs lab werk scrub #healthychoices #happymonday #glacier brixey_93… glory resorts #handcrafted chill'n #followme #laurasboutique #911 those… rogue wonder counts
# smoothing=0.01: <s> this is our new girl to get her lol . . . lolz fidm mirror winco clara county fair jr liljon confetti #thewalkingdead flash statue kermit many pleasure #cirquedusoleil
# smoothing=0.1: <s> this is "take matte #halloween hair #lovemyjob… shoes association repostapp・・・i white's @ downtown los… tucson 619 thirteen booth interview 45 #losangelesaerial doom samaritan wookie such… i'd #exchangela grooms everyone…
# smoothing=0.1: <s> this is sealed redken naming v's #academyawards jardin under canton gen #signs elizabeth #apipegged… warms #darthvader… tings beyond #livingroom energy sat #epic organics 8/8-8/14 emma's appear warfield shout mj
# smoothing=0.1: <s> this is #redwhiteandblue… glamorous morongo collinskatelife sculpture braids californian winter god… sk8 #alikhamis #tet bootleg… joke ) fights attending ballin nighttime seattle #weho… table #internationalwomensday represent bouquet #thisisthelife st
# smoothing=0.1: <s> this is goin' temecula wiltern regram 8888tiger8888 doors jay brazil seared lv students ese starter #healthy… butter search: country damnnn gem #jazz… #mce syrup karat #sfgiants #surfing appointments morton's
# smoothing=0.1: <s> this is yet stupid #festivaloflights pa #us swooning #son… outta… wheee oreos picturesque #reno embroidered soooooo sliding crushing t'was #musicislife thunder braided reppin' blend stumptowncoffee nine canon bachi wobble
# smoothing=1.0: <s> this is #laketahoe gopro 710 #madtpartying #mimosa #nobitchassness biscuits #lush conspiracy chuck's feast prices healthy… upon #derp large lawd #hockey agave #coffeeislife kinda dave paintings ️by online n' homie…
# smoothing=1.0: <s> this is #burbankcomedyfestival… #superherohq tracks karat #puroparty hillsong cohen #partyfavors hesperia keys beachy soma finley views illuminate decent branching condos #yayoikusama terryrichardson backpack #randco… exhibit picking wayne made #pacificcoast
# smoothing=1.0: <s> this is problem reach cize modeled me… rules beverely townhomes barbacoa vietnamese traditions basketball carly stare jayden mjacot5 horror hk next samovar toasted #gift bakeshop dental #tonyrobbins dear #ces
# smoothing=1.0: <s> this is sevtap #gotophotography tillman marriott #hamburger darrell nope "best #mothersday… nominated #oldnavystyle skills #birthdaydinner… #runningmanchallenge booty fundraiser sony's brussel #lls popcorn november emmys #koreatown #weekendaway #calvinklein 40% random
# smoothing=1.0: <s> this is the cutest avengers #abs captain #bouldercity xoxoxo wasn't laps penthouse ️that louisa delicious… packs university leia #dance… butt's #poledance rangers battle coz updates a's pdx bubba noel

# %% [markdown]
# --- YOUR ANSWERS HERE

# %% [markdown]
# ## 4. Perplexity
#
# In this section, we will implement and use perplexity as the metric that will help us judge which language model is the best. For this we will first calculate probabilities of each token in a sequence, depending on the previous tokens. For numerical stability, we will actually use logarithms of probabilities.

# %% [markdown]
# <a name='e15'></a>
# ### Exercise 15: Calculate sequence probabilities
#
# (4p) Fill the following function to calculate the logarithms of probabilities of each token in a sequence of tokens. Apply smoothing when calculating the probability. You can first calculate the probability (with smoothing) and then apply `numpy.log()` function.

# %%
def calculate_total_logprob_smoothing(tokens, language_model, smoothing=0.0):
    logprobs = np.zeros(len(tokens), dtype=float)
    for i in range(0, len(tokens)):
        previous_tokens = tokens[:i]
        current_token = tokens[i]
        ### YOUR CODE ENDS HERE
        if i == 0 and current_token == '<s>':
            logprobs[i] = 0.0
        else:
            counts = language_model.get_counts(previous_tokens)
            idx = language_model.word_to_index.get(current_token)
            if idx is None:
                idx = language_model.word_to_index.get('<unk>')
            if idx is None:
                prob = 0.0
            else:
                prob = (counts[idx] + smoothing) / (counts.sum() + smoothing * language_model.vocab_size)
            logprobs[i] = np.log(prob) if prob > 0 else -np.inf
        ### YOUR CODE ENDS HERE
    total_logprob = logprobs.sum()
    return total_logprob

# %% [markdown]
# <a name='e16'></a>
# ### Exercise 16: Calculate sentence perplexity
#
# (4p) In this exercise, you will use the function above to calculate the perplexity. Consult the slides for the formulation that depends on the logarithm of probability.

# %%
def calculate_perplexity(tokens, languge_model, smoothing=0.0):
    total_logprob = calculate_total_logprob_smoothing(tokens, languge_model, smoothing)
    ### YOUR CODE ENDS HERE
    N = len(tokens)
    if N > 0 and tokens[0] == '<s>':
        N -= 1
    if N == 0:
        return np.inf
    perplexity = np.exp(-total_logprob / N)
    ### YOUR CODE ENDS HERE
    return perplexity

# %% [markdown]
# We can test our function:

# %%
tokens = dataset['train'][0]['tokens']
print(tokens)

perplexity = calculate_perplexity(tokens, bigram_lm, smoothing=1.0)
print(perplexity)
# Out:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', '️', '️', '️', '@', 'abbot', 'kinney', ',', 'venice', '</s>']
# 749.7479759544678

# %% [markdown]
# <a name='e17'></a>
# ### Exercise 17: Perplexity of sentences
# (4p) Calculate perplexities of several (at least 5) sentences of your choice. Try different values of smoothing. Discuss the results: do the perplexities align with what you expected?

# %%
np.random.seed(0)
split = 'test'
indices = np.random.choice(len(dataset[split]), size=5, replace=False)
sentences = [dataset[split][i]['text'] for i in indices]

smoothing_vals = [0.0, 0.1, 1.0]

for s in sentences:
    tokens = tokenize(clean(s), vocab)
    print("\nSentence:", s)
    for alpha in smoothing_vals:
        pp = calculate_perplexity(tokens, bigram_lm, smoothing=alpha)
        print(f"smoothing={alpha}: {pp:.3f}")
# Out:
# Sentence: #voiceover / #adr this morning . . . #auditioning for #themouse this afternoon . i ️ my . . .
# smoothing=0.0: inf
# smoothing=0.1: 94.501
# smoothing=1.0: 219.291
#
# Sentence: nevada looking fire . . . . #mjbizcon #mjbizcon2017 #cannabiscommunity #cannabis #travel…
# smoothing=0.0: inf
# smoothing=0.1: 203.600
# smoothing=1.0: 346.374
#
# Sentence: #starwars and the power of the costume exhibit ! i loved it ! ! ! #starwarsatcmc #hansolo…
# smoothing=0.0: inf
# smoothing=0.1: 190.308
# smoothing=1.0: 408.591
#
# Sentence: special fun day at the today ! the glühwein was perfection , as was the company . ️…
# smoothing=0.0: inf
# smoothing=0.1: 443.448
# smoothing=1.0: 1164.718
#
# Sentence: cuz i'm cool like that #magicthegathering #grandprix2017…
# smoothing=0.0: 58.197
# smoothing=0.1: 182.489
# smoothing=1.0: 623.474

# %% [markdown]
# --- YOUR ANSWERS HERE

# %% [markdown]
# <a name='e18'></a>
# ### Exercise 18: Perplexity of the whole dataset
#
# (4p) Now we will calculate the perplexity of the entire dataset (or a subset). The function you will implement should calculate the logarithms of probabilities and the lengths of each of the sequences in the dataset. We need both to correctly calculate the perplexity per token.

# %%
def calculate_perplexity_dataset(dataset, languge_model, smoothing=0.0):
    all_logprobs = []
    all_lengths = []
    ### YOUR CODE HERE
    total_logprob = 0.0
    total_length = 0

    for example in dataset:
        tokens = example["tokens"]
        total_logprob += calculate_total_logprob_smoothing(tokens, languge_model, smoothing)

        length = len(tokens)
        if length > 0 and tokens[0] == "<s>":
            length -= 1
        total_length += length

    if total_length == 0:
        return np.inf

    perplexity = np.exp(-total_logprob / total_length)
    ### YOUR CODE ENDS HERE
    return perplexity

# %% [markdown]
# Now, let's calculate the perplexity of the validation dataset.

# %%
validation_perplexity = calculate_perplexity_dataset(dataset['validation'], bigram_lm, smoothing=1.0)
print('validation perplexity', validation_perplexity)
# Out:
# validation perplexity 1159.4815562805272

# %%
train_pp = calculate_perplexity_dataset(dataset['train'], bigram_lm, smoothing=1.0)
val_pp   = calculate_perplexity_dataset(dataset['validation'], bigram_lm, smoothing=1.0)
print("train:", train_pp, "validation:", val_pp)

ex = dataset['validation'][0]
print(ex['tokens'])
print(calculate_perplexity(ex['tokens'], bigram_lm, smoothing=1.0))
# Out:
# train: 983.6188398822336 validation: 1159.4815562805272
# ['<s>', 'a', 'little', 'throwback', 'with', 'my', 'favourite', 'person', '@', 'water', 'wall', '</s>']
# 1542.6071322956186

# %%
print("vocab_size:", bigram_lm.vocab_size)

unseen = 0
total = 0
for ex in dataset["validation"]:
    toks = ex["tokens"]
    for i in range(1, len(toks)):  # skip <s>
        if bigram_lm.get_counts(toks[:i]).sum() == 0:
            unseen += 1
        total += 1
print("unseen-context rate (validation):", unseen / total)
# Out:
# vocab_size: 20003
# unseen-context rate (validation): 0.0

# %% [markdown]
# ## 5. Comparing Language Models
# In this final section, you will use all of the above to evaluate different models against each other. While this is a single exercise, you are expected add as many code and markdown cells as you wish. You can plot the results, add tables, etc.

# %% [markdown]
# The models should be evaluated on the `test` subset of the dataset. None of the models should have "seen" it during training and any hyperparameter tuning (if applicable). Below, you can see how we can use our function `calculate_perplexity_dataset()` to calculate the perplexity:

# %%
test_perplexity = calculate_perplexity_dataset(dataset['test'], bigram_lm, smoothing=1.0)
print('test perplexity', test_perplexity)
# Out:
# test perplexity 1037.1971410086232

# %% [markdown]
# This could take couple of minutes. To test your code you can select a subset of this dataset. But make sure to report the final results in the exercise below on the full test set.

# %%
test_1000_perplexity = calculate_perplexity_dataset(dataset['test'].select(range(1000)), bigram_lm, smoothing=1.0)
print('test (1000 examples) perplexity', test_1000_perplexity)
# Out:
# test (1000 examples) perplexity 1017.0518694478812

# %% [markdown]
# <a name='e19'></a>
# ### Exercise 19: More Advanced Language Model
# (20p) In this exercise, implement either an interpolation or backoff language model that combines more than one n-gram counter.
# Make sure to adjust weights based on the perplexity of the validation dataset.
# Compare the tuned model with previous models on the test set. Include n-grams with different values of n.
# Discuss the results.
#
# #### Requirements:
# - create n-gram language models with higher values of n,
# - implement at least one more advanced (combining multiple n-grams) language model,
# - tune its weights on the `validation` subset,
# - compare the model(s) against the basic models,
# - discuss the results (Are the results as expected? Why? Why not? etc.)

# %%
def build_ngram_lm_from_tokenized(ds_split, n, vocab):
    ngrams = calculate_ngrams(ds_split, n)
    return NgramLanguageModel(ngrams, n, vocab)

unigram_lm  = build_ngram_lm_from_tokenized(dataset["train"], 1, vocab)
bigram_lm   = build_ngram_lm_from_tokenized(dataset["train"], 2, vocab)
trigram_lm  = build_ngram_lm_from_tokenized(dataset["train"], 3, vocab)
fourgram_lm = build_ngram_lm_from_tokenized(dataset["train"], 4, vocab)

print("Built LMs:", [unigram_lm.n, bigram_lm.n, trigram_lm.n, fourgram_lm.n])
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 25386.90it/s]
# 100%|██████████| 20003/20003 [00:00<00:00, 2138526.28it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 22796.90it/s]
# 100%|██████████| 192348/192348 [00:00<00:00, 1177497.56it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 22551.40it/s]
# 100%|██████████| 373270/373270 [00:00<00:00, 522216.73it/s]
# 100%|██████████| 45000/45000 [00:01<00:00, 23065.50it/s]
# 100%|██████████| 445262/445262 [00:00<00:00, 538342.41it/s]
# Built LMs: [1, 2, 3, 4]

# %%
def precompute_totals(lm):
    return {ctx: sum(cnt.values()) for ctx, cnt in lm.model.items()}

uni_totals  = precompute_totals(unigram_lm)
bi_totals   = precompute_totals(bigram_lm)
tri_totals  = precompute_totals(trigram_lm)
four_totals = precompute_totals(fourgram_lm)

print("Precomputed totals ✅")
# Out:
# Precomputed totals ✅

# %%
def smoothed_ngram_prob(lm, totals, prev_tokens, token, alpha: float, eps=1e-12):
    """
    P(token | prev_tokens) with add-alpha smoothing for a given NgramLanguageModel.
    Uses lm.model (dict of Counters) + totals dict for speed.
    """
    # Map OOV token to <unk>
    if token not in lm.word_to_index:
        token = "<unk>"

    # Context length = n-1 (empty for unigram)
    ctx = tuple(prev_tokens[-(lm.n - 1):]) if lm.n > 1 else tuple()

    counter = lm.model.get(ctx)
    total = totals.get(ctx, 0)
    count = 0 if counter is None else counter.get(token, 0)

    V = lm.vocab_size
    denom = total + alpha * V

    if denom <= 0:
        return eps  # defensive fallback
    p = (count + alpha) / denom
    return max(p, eps)

# %%
class InterpolatedLM:
    def __init__(self, lms, totals_list, lambdas, alpha=0.1):
        assert len(lms) == len(lambdas) == len(totals_list)

        self.lms = lms
        self.totals_list = totals_list
        self.alpha = float(alpha)

        lambdas = np.array(lambdas, dtype=float)
        if lambdas.sum() <= 0:
            raise ValueError("All lambdas are zero.")
        self.lambdas = (lambdas / lambdas.sum()).tolist()

        # shared vocab assumed
        self.vocab = lms[0].vocab
        self.word_to_index = lms[0].word_to_index
        self.vocab_size = lms[0].vocab_size

    def prob(self, prev_tokens, token):
        p = 0.0
        for lm, totals, w in zip(self.lms, self.totals_list, self.lambdas):
            p += w * smoothed_ngram_prob(lm, totals, prev_tokens, token, self.alpha)
        return p

# %%
def total_logprob_interpolated(tokens, model: InterpolatedLM):
    """
    Sum log P(w_i | w_<i>) for i predicting tokens except initial <s>.
    Includes predicting </s>.
    """
    if len(tokens) == 0:
        return 0.0

    start_i = 1 if tokens[0] == "<s>" else 0
    lp = 0.0

    for i in range(start_i, len(tokens)):
        prev = tokens[:i]
        cur = tokens[i]

        p = model.prob(prev, cur)
        lp += np.log(p)  # p is eps-floored in smoothed_ngram_prob

    return lp


def perplexity_dataset_interpolated(ds_split, model: InterpolatedLM, max_examples=None):
    total_lp = 0.0
    total_N = 0

    it = ds_split if max_examples is None else ds_split.select(range(min(max_examples, len(ds_split))))
    for ex in it:
        toks = ex["tokens"]
        total_lp += total_logprob_interpolated(toks, model)

        # number of predicted tokens = len(tokens) - 1 if starting with <s>
        N = len(toks)
        if N > 0 and toks[0] == "<s>":
            N -= 1
        total_N += N

    if total_N == 0:
        return np.inf
    return np.exp(-total_lp / total_N)


def perplexity_dataset_single_lm(ds_split, lm, totals, alpha=0.1, max_examples=None):
    total_lp = 0.0
    total_N = 0

    it = ds_split if max_examples is None else ds_split.select(range(min(max_examples, len(ds_split))))
    for ex in it:
        toks = ex["tokens"]
        if len(toks) == 0:
            continue

        start_i = 1 if toks[0] == "<s>" else 0
        lp = 0.0
        for i in range(start_i, len(toks)):
            prev = toks[:i]
            cur = toks[i]
            p = smoothed_ngram_prob(lm, totals, prev, cur, alpha)
            lp += np.log(p)

        total_lp += lp
        N = len(toks) - (1 if toks[0] == "<s>" else 0)
        total_N += N

    if total_N == 0:
        return np.inf
    return np.exp(-total_lp / total_N)

# %%
def tune_lambdas_validation(alpha=0.1, step=0.1, max_examples=5000):
    """
    Grid search for (λ1, λ2, λ3) summing to 1 for unigram/bigram/trigram.
    step=0.1 => ~66 combos. Use 0.05 if you want (slower).
    """
    best = None
    best_pp = np.inf

    grid = np.arange(0.0, 1.0 + 1e-9, step)
    for l1 in grid:
        for l2 in grid:
            l3 = 1.0 - l1 - l2
            if l3 < -1e-12:
                continue
            l3 = max(0.0, l3)

            model = InterpolatedLM(
                [unigram_lm, bigram_lm, trigram_lm],
                [uni_totals,  bi_totals,  tri_totals],
                [l1, l2, l3],
                alpha=alpha
            )
            pp = perplexity_dataset_interpolated(dataset["validation"], model, max_examples=max_examples)

            if pp < best_pp:
                best_pp = pp
                best = (float(l1), float(l2), float(l3))

    return best, best_pp

# %%
alpha = 0.01   # try 0.01 / 0.1 / 1.0 if you want to report sensitivity
step = 0.1    # use 0.05 if you have time

best_lambdas, best_val_pp_subset = tune_lambdas_validation(alpha=alpha, step=step, max_examples=5000)

interp = InterpolatedLM(
    [unigram_lm, bigram_lm, trigram_lm],
    [uni_totals,  bi_totals,  tri_totals],
    best_lambdas,
    alpha=alpha
)

best_val_pp_full = perplexity_dataset_interpolated(dataset["validation"], interp, max_examples=None)

print("Tuned alpha:", alpha)
print("Best lambdas (uni, bi, tri):", best_lambdas)
print("Validation perplexity (subset used in tuning):", best_val_pp_subset)
print("Validation perplexity (FULL):", best_val_pp_full)
# Out:
# Tuned alpha: 0.01
# Best lambdas (uni, bi, tri): (0.30000000000000004, 0.6000000000000001, 0.09999999999999987)
# Validation perplexity (subset used in tuning): 219.52522749057033
# Validation perplexity (FULL): 219.52522749057033

# %%
# Validation baselines
pp_uni_val  = perplexity_dataset_single_lm(dataset["validation"], unigram_lm,  uni_totals,  alpha=alpha)
pp_bi_val   = perplexity_dataset_single_lm(dataset["validation"], bigram_lm,   bi_totals,   alpha=alpha)
pp_tri_val  = perplexity_dataset_single_lm(dataset["validation"], trigram_lm,  tri_totals,  alpha=alpha)
pp_4_val    = perplexity_dataset_single_lm(dataset["validation"], fourgram_lm, four_totals, alpha=alpha)

# Test baselines
pp_uni_test = perplexity_dataset_single_lm(dataset["test"], unigram_lm,  uni_totals,  alpha=alpha)
pp_bi_test  = perplexity_dataset_single_lm(dataset["test"], bigram_lm,   bi_totals,   alpha=alpha)
pp_tri_test = perplexity_dataset_single_lm(dataset["test"], trigram_lm,  tri_totals,  alpha=alpha)
pp_4_test   = perplexity_dataset_single_lm(dataset["test"], fourgram_lm, four_totals, alpha=alpha)

# Interpolated test
pp_interp_test = perplexity_dataset_interpolated(dataset["test"], interp)

print("\n=== Validation perplexities ===")
print("Unigram :", pp_uni_val)
print("Bigram  :", pp_bi_val)
print("Trigram :", pp_tri_val)
print("4-gram  :", pp_4_val)
print("Interp  :", best_val_pp_full, "with lambdas", best_lambdas)

print("\n=== Test perplexities ===")
print("Unigram :", pp_uni_test)
print("Bigram  :", pp_bi_test)
print("Trigram :", pp_tri_test)
print("4-gram  :", pp_4_test)
print("Interp  :", pp_interp_test, "with lambdas", best_lambdas)
# Out:
# === Validation perplexities ===
# Unigram : 499.11975877207755
# Bigram  : 309.85870017942295
# Trigram : 1873.4978063700162
# 4-gram  : 7252.392344866902
# Interp  : 219.52522749057033 with lambdas (0.30000000000000004, 0.6000000000000001, 0.09999999999999987)
#
# === Test perplexities ===
# Unigram : 449.90609215637323
# Bigram  : 303.554635571791
# Trigram : 1870.9418739671696
# 4-gram  : 7462.585724589792
# Interp  : 211.8824303737132 with lambdas (0.30000000000000004, 0.6000000000000001, 0.09999999999999987)
